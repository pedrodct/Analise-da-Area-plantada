# %%
# logica de programação

# 3 Analise: Fazer analise de Agua Boa-MT

# Tarefas:
# Baixar o banco de dados utilizando modelos usados na analise 2
# Separar a safra (19/20, 20/21 e 21/22) de agua boa-MT
# Gerar informações

# %%
import pandas as pd
import numpy as np

# %%
# Copiando o codigo da analise 1 do IBGE

#Importando a planilha Excel do IBGE
ibge= pd.read_excel('tabela1612.xlsx')
ibge.drop(ibge.loc[(ibge['Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias'] == 'MI') | (ibge['Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias'] == 'ME')].index, inplace=True)

display(ibge)
# Out:
#      Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias  \
# 0                              Variável - Área plantada
# 1                                                 Nível
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    BR
# ...                                                 ...
# 5592                                                 MU
# 5593                                                 MU
# 5594                                                 MU
# 5595                                                 MU
# 6291          Fonte: IBGE - Produção Agrícola Municipal
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1     Brasil, Unidade da Federação, Município, Mesor...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                Brasil
# ...                                                 ...
# 5592                                Vicentinópolis (GO)
# 5593                                      Vila Boa (GO)
# 5594                                 Vila Propício (GO)
# 5595                                      Brasília (DF)
# 6291                                                NaN
#
#                                   Unnamed: 2 Unnamed: 3      Unnamed: 4  \
# 0                                        NaN        NaN             NaN
# 1     Ano x Produto das lavouras temporárias        NaN             NaN
# 2                                       2019        NaN            2020
# 3                             Soja (em grão)        NaN  Soja (em grão)
# 4                                   35944094   Hectares        37205462
# ...                                      ...        ...             ...
# 5592                                   20400   Hectares           21000
# 5593                                     250   Hectares             250
# 5594                                   16500   Hectares           16700
# 5595                                   75000   Hectares           74500
# 6291                                     NaN        NaN             NaN
#
#      Unnamed: 5      Unnamed: 6 Unnamed: 7
# 0           NaN             NaN        NaN
# 1           NaN             NaN        NaN
# 2           NaN            2021        NaN
# 3           NaN  Soja (em grão)        NaN
# 4      Hectares        39185745   Hectares
# ...         ...             ...        ...
# 5592   Hectares           24500   Hectares
# 5593   Hectares            1800   Hectares
# 5594   Hectares           22950   Hectares
# 5595   Hectares           80000   Hectares
# 6291        NaN             NaN        NaN
#
# [5597 rows x 8 columns]

# %%
# Renomeando o cabecalho e dropando linhas desnecessarias

new_columns = {'Unnamed: 1': 'Cidade', 
               'Unnamed: 2': '2019',
               'Unnamed: 3': 'Unidade de medida',
               'Unnamed: 4': '2020',
               'Unnamed: 5': 'Unidade de medida',
               'Unnamed: 6': '2021',
               'Unnamed: 7': 'Unidade de medida'}

area_plantada_ibge = ibge.rename(columns=new_columns)

area_plantada_ibge.head(35)
# Out:
#    Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias  \
# 0                            Variável - Área plantada
# 1                                               Nível
# 2                                                 NaN
# 3                                                 NaN
# 4                                                  BR
# 5                                                  UF
# 6                                                  UF
# 7                                                  UF
# 8                                                  UF
# 9                                                  UF
# 10                                                 UF
# 11                                                 UF
# 12                                                 UF
# 13                                                 UF
# 14                                                 UF
# 15                                                 UF
# 16                                                 UF
# 17                                                 UF
# 18                                                 UF
# 19                                                 UF
# 20                                                 UF
# 21                                                 UF
# 22                                                 UF
# 23                                                 UF
# 24                                                 UF
# 25                                                 UF
# 26                                                 UF
# 27                                                 UF
# 28                                                 UF
# 29                                                 UF
# 30                                                 UF
# 31                                                 UF
# 32                                                 UF
# 33                                                 MU
# 34                                                 MU
#
#                                                Cidade  \
# 0                                                 NaN
# 1   Brasil, Unidade da Federação, Município, Mesor...
# 2                                                 NaN
# 3                                                 NaN
# 4                                              Brasil
# 5                                            Rondônia
# 6                                                Acre
# 7                                            Amazonas
# 8                                             Roraima
# 9                                                Pará
# 10                                              Amapá
# 11                                          Tocantins
# 12                                           Maranhão
# 13                                              Piauí
# 14                                              Ceará
# 15                                Rio Grande do Norte
# 16                                            Paraíba
# 17                                         Pernambuco
# 18                                            Alagoas
# 19                                            Sergipe
# 20                                              Bahia
# 21                                       Minas Gerais
# 22                                     Espírito Santo
# 23                                     Rio de Janeiro
# 24                                          Guanabara
# 25                                          São Paulo
# 26                                             Paraná
# 27                                     Santa Catarina
# 28                                  Rio Grande do Sul
# 29                                 Mato Grosso do Sul
# 30                                        Mato Grosso
# 31                                              Goiás
# 32                                   Distrito Federal
# 33                         Alta Floresta D'Oeste (RO)
# 34                                     Ariquemes (RO)
#
#                                       2019 Unidade de medida            2020  \
# 0                                      NaN               NaN             NaN
# 1   Ano x Produto das lavouras temporárias               NaN             NaN
# 2                                     2019               NaN            2020
# 3                           Soja (em grão)               NaN  Soja (em grão)
# 4                                 35944094          Hectares        37205462
# 5                                   344551          Hectares          392642
# 6                                     1660          Hectares            3280
# 7                                     2500          Hectares            2700
# 8                                    39930          Hectares           49800
# 9                                   577764          Hectares          643267
# 10                                   19476          Hectares           20300
# 11                                  905281          Hectares          962399
# 12                                  977598          Hectares          960900
# 13                                  766044          Hectares          757978
# 14                                       -          Hectares             450
# 15                                       -          Hectares               -
# 16                                       -          Hectares               -
# 17                                       -          Hectares               -
# 18                                    3141          Hectares            1224
# 19                                       -          Hectares               -
# 20                                 1585842          Hectares         1622475
# 21                                 1627741          Hectares         1695702
# 22                                       -          Hectares               -
# 23                                       -          Hectares               -
# 24                                     ...          Hectares             ...
# 25                                 1080541          Hectares         1132965
# 26                                 5418814          Hectares         5534843
# 27                                  665548          Hectares          664795
# 28                                 5843533          Hectares         5996371
# 29                                 2882107          Hectares         3121522
# 30                                 9724213          Hectares         9989649
# 31                                 3402810          Hectares         3577700
# 32                                   75000          Hectares           74500
# 33                                     450          Hectares             450
# 34                                    7893          Hectares            7782
#
#    Unidade de medida            2021 Unidade de medida
# 0                NaN             NaN               NaN
# 1                NaN             NaN               NaN
# 2                NaN            2021               NaN
# 3                NaN  Soja (em grão)               NaN
# 4           Hectares        39185745          Hectares
# 5           Hectares          400459          Hectares
# 6           Hectares            6185          Hectares
# 7           Hectares            3000          Hectares
# 8           Hectares           57277          Hectares
# 9           Hectares          753781          Hectares
# 10          Hectares            6715          Hectares
# 11          Hectares         1171308          Hectares
# 12          Hectares         1023541          Hectares
# 13          Hectares          832063          Hectares
# 14          Hectares            1414          Hectares
# 15          Hectares               -          Hectares
# 16          Hectares               -          Hectares
# 17          Hectares             300          Hectares
# 18          Hectares            3312          Hectares
# 19          Hectares               -          Hectares
# 20          Hectares         1699965          Hectares
# 21          Hectares         1935260          Hectares
# 22          Hectares               -          Hectares
# 23          Hectares               -          Hectares
# 24          Hectares             ...          Hectares
# 25          Hectares         1199351          Hectares
# 26          Hectares         5521183          Hectares
# 27          Hectares          688980          Hectares
# 28          Hectares         6107620          Hectares
# 29          Hectares         3377042          Hectares
# 30          Hectares        10461712          Hectares
# 31          Hectares         3855277          Hectares
# 32          Hectares           80000          Hectares
# 33          Hectares            1072          Hectares
# 34          Hectares            6979          Hectares

# %%
# não há necessidade dos dados da coluna 1,3,4 e 5 assim como das linhas até 32. Excluir.

area_plantada_ibge1 = area_plantada_ibge.drop(index=range(0,33), axis=0)
area_plantada_ibge1.drop(['2019', 'Unidade de medida','2020', 	
                          'Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias']
                         , axis=1 , inplace=True)
area_plantada_ibge1 = area_plantada_ibge.drop(index=6291, axis=0)

display(area_plantada_ibge1)
# Out:
#      Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias  \
# 0                              Variável - Área plantada
# 1                                                 Nível
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    BR
# ...                                                 ...
# 5591                                                 MU
# 5592                                                 MU
# 5593                                                 MU
# 5594                                                 MU
# 5595                                                 MU
#
#                                                  Cidade  \
# 0                                                   NaN
# 1     Brasil, Unidade da Federação, Município, Mesor...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                Brasil
# ...                                                 ...
# 5591                                    Vianópolis (GO)
# 5592                                Vicentinópolis (GO)
# 5593                                      Vila Boa (GO)
# 5594                                 Vila Propício (GO)
# 5595                                      Brasília (DF)
#
#                                         2019 Unidade de medida  \
# 0                                        NaN               NaN
# 1     Ano x Produto das lavouras temporárias               NaN
# 2                                       2019               NaN
# 3                             Soja (em grão)               NaN
# 4                                   35944094          Hectares
# ...                                      ...               ...
# 5591                                   40000          Hectares
# 5592                                   20400          Hectares
# 5593                                     250          Hectares
# 5594                                   16500          Hectares
# 5595                                   75000          Hectares
#
#                 2020 Unidade de medida            2021 Unidade de medida
# 0                NaN               NaN             NaN               NaN
# 1                NaN               NaN             NaN               NaN
# 2               2020               NaN            2021               NaN
# 3     Soja (em grão)               NaN  Soja (em grão)               NaN
# 4           37205462          Hectares        39185745          Hectares
# ...              ...               ...             ...               ...
# 5591           41000          Hectares           41000          Hectares
# 5592           21000          Hectares           24500          Hectares
# 5593             250          Hectares            1800          Hectares
# 5594           16700          Hectares           22950          Hectares
# 5595           74500          Hectares           80000          Hectares
#
# [5596 rows x 8 columns]

# %%
area_plantada_ibge1 = area_plantada_ibge.drop(index=range(0,33), axis=0)
area_plantada_ibge1.drop([ 'Unidade de medida', 	
                          'Tabela 1612 - Área plantada, área colhida, quantidade produzida, rendimento médio e valor da produção das lavouras temporárias']
                         , axis=1 , inplace=True)

display(area_plantada_ibge1)
# Out:
#                           Cidade   2019   2020   2021
# 33    Alta Floresta D'Oeste (RO)    450    450   1072
# 34                Ariquemes (RO)   7893   7782   6979
# 35                   Cabixi (RO)  24630  24950  27705
# 36                   Cacoal (RO)   1000   1000   2160
# 37               Cerejeiras (RO)  35190  36150  36430
# ...                          ...    ...    ...    ...
# 5592         Vicentinópolis (GO)  20400  21000  24500
# 5593               Vila Boa (GO)    250    250   1800
# 5594          Vila Propício (GO)  16500  16700  22950
# 5595               Brasília (DF)  75000  74500  80000
# 6291                         NaN    NaN    NaN    NaN
#
# [5564 rows x 4 columns]

# %%
area_plantada_ibge1.drop(6291, inplace=True)

display(area_plantada_ibge1)
# Out:
#                           Cidade   2019   2020   2021
# 33    Alta Floresta D'Oeste (RO)    450    450   1072
# 34                Ariquemes (RO)   7893   7782   6979
# 35                   Cabixi (RO)  24630  24950  27705
# 36                   Cacoal (RO)   1000   1000   2160
# 37               Cerejeiras (RO)  35190  36150  36430
# ...                          ...    ...    ...    ...
# 5591             Vianópolis (GO)  40000  41000  41000
# 5592         Vicentinópolis (GO)  20400  21000  24500
# 5593               Vila Boa (GO)    250    250   1800
# 5594          Vila Propício (GO)  16500  16700  22950
# 5595               Brasília (DF)  75000  74500  80000
#
# [5563 rows x 4 columns]

# %%
# Separar a cidade e o estado em duas colunas
area_plantada_ibge1[['Cidade', 'Estado']] = area_plantada_ibge1['Cidade'].str.split("(", expand=True)
area_plantada_ibge1['Sigla'] = area_plantada_ibge1['Estado'].str.extract(r'([A-Z]{2})')
area_plantada_ibge1['Estado'] = area_plantada_ibge1['Estado'].str.replace(r'\(|\)|[A-Z]{2}', '')
area_plantada_ibge1['Cidade'] = area_plantada_ibge1['Cidade'].str.strip()
area_plantada_ibge1['Estado'] = area_plantada_ibge1['Estado'].str.strip()

display(area_plantada_ibge1)
# Out:
# C:\Users\PEDRO\AppData\Local\Temp\ipykernel_3780\3999825676.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   area_plantada_ibge1['Estado'] = area_plantada_ibge1['Estado'].str.replace(r'\(|\)|[A-Z]{2}', '')
#                      Cidade   2019   2020   2021 Estado Sigla
# 33    Alta Floresta D'Oeste    450    450   1072           RO
# 34                Ariquemes   7893   7782   6979           RO
# 35                   Cabixi  24630  24950  27705           RO
# 36                   Cacoal   1000   1000   2160           RO
# 37               Cerejeiras  35190  36150  36430           RO
# ...                     ...    ...    ...    ...    ...   ...
# 5591             Vianópolis  40000  41000  41000           GO
# 5592         Vicentinópolis  20400  21000  24500           GO
# 5593               Vila Boa    250    250   1800           GO
# 5594          Vila Propício  16500  16700  22950           GO
# 5595               Brasília  75000  74500  80000           DF
#
# [5563 rows x 6 columns]

# %%
area_plantada_ibge1.loc[area_plantada_ibge1['Cidade'] == 'Água Boa']
display(area_plantada_ibge1)
# Out:
#                      Cidade   2019   2020   2021 Estado Sigla
# 33    Alta Floresta D'Oeste    450    450   1072           RO
# 34                Ariquemes   7893   7782   6979           RO
# 35                   Cabixi  24630  24950  27705           RO
# 36                   Cacoal   1000   1000   2160           RO
# 37               Cerejeiras  35190  36150  36430           RO
# ...                     ...    ...    ...    ...    ...   ...
# 5591             Vianópolis  40000  41000  41000           GO
# 5592         Vicentinópolis  20400  21000  24500           GO
# 5593               Vila Boa    250    250   1800           GO
# 5594          Vila Propício  16500  16700  22950           GO
# 5595               Brasília  75000  74500  80000           DF
#
# [5563 rows x 6 columns]

# %%
# Filtrar apenas a cidade de Água Boa
agua_boa = area_plantada_ibge1[area_plantada_ibge1['Cidade'] == 'Água Boa']

display(agua_boa)
# Out:
#         Cidade    2019    2020    2021 Estado Sigla
# 2281  Água Boa       -       -       -           MG
# 5209  Água Boa  160000  178000  175000           MT

# %%
# Criando um Groupby para o MT

group = area_plantada_ibge1.loc[area_plantada_ibge1['Sigla'] == 'MT', ['Sigla', '2019', '2020', '2021']].groupby('Sigla', numeric_only=True).sum()

print(group)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3780\3603001232.py in <module>
#       1 # Criando um Groupby para o MT
#       2
# ----> 3 group = area_plantada_ibge1.loc[area_plantada_ibge1['Sigla'] == 'MT', ['Sigla', '2019', '2020', '2021']].groupby('Sigla', numeric_only=True).sum()
#       4
#       5 print(group)
#
# TypeError: groupby() got an unexpected keyword argument 'numeric_only'

# %%
area_plantada_ibge1.describe()
# Out:
#            Cidade  2019  2020  2021 Estado Sigla
# count        5563  5563  5563  5563   5563  5563
# unique       5290   985  1018  1019      1    27
# top     Bom Jesus     -     -     -           MG
# freq            5  3126  3100  3024   5563   853

# %%
area_plantada_ibge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5563 entries, 33 to 5595
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cidade  5563 non-null   object
#  1   2019    5563 non-null   object
#  2   2020    5563 non-null   object
#  3   2021    5563 non-null   object
#  4   Estado  5563 non-null   object
#  5   Sigla   5563 non-null   object
# dtypes: object(6)
# memory usage: 304.2+ KB

# %%
# Transformando a colunas em numeros
area_plantada_ibge1['2019'] = area_plantada_ibge1['2019'].astype(float).round(0)
area_plantada_ibge1['2020'] = area_plantada_ibge1['2020'].astype(float).round(0)
area_plantada_ibge1['2021'] = area_plantada_ibge1['2021'].astype(float).round(0)

area_plantada_ibge1.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3780\604805083.py in <module>
#       1 # Transformando a colunas em numeros
# ----> 2 area_plantada_ibge1['2019'] = area_plantada_ibge1['2019'].astype(float).round(0)
#       3 area_plantada_ibge1['2020'] = area_plantada_ibge1['2020'].astype(float).round(0)
#       4 area_plantada_ibge1['2021'] = area_plantada_ibge1['2021'].astype(float).round(0)
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
area_plantada_ibge1.loc[area_plantada_ibge1['2019'] == '-', '2019'] = 0
area_plantada_ibge1.loc[area_plantada_ibge1['2020'] == '-', '2020'] = 0
area_plantada_ibge1.loc[area_plantada_ibge1['2021'] == '-', '2021'] = 0

area_plantada_ibge1['2019'] = area_plantada_ibge1['2019'].astype(float).round(0)
area_plantada_ibge1['2020'] = area_plantada_ibge1['2020'].astype(float).round(0)
area_plantada_ibge1['2021'] = area_plantada_ibge1['2021'].astype(float).round(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3780\1241388761.py in <module>
#       3 area_plantada_ibge1.loc[area_plantada_ibge1['2021'] == '-', '2021'] = 0
#       4
# ----> 5 area_plantada_ibge1['2019'] = area_plantada_ibge1['2019'].astype(float).round(0)
#       6 area_plantada_ibge1['2020'] = area_plantada_ibge1['2020'].astype(float).round(0)
#       7 area_plantada_ibge1['2021'] = area_plantada_ibge1['2021'].astype(float).round(0)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '...'

# %%
area_plantada_ibge1.loc[area_plantada_ibge1['2019'] == '...', '2019'] = 0
area_plantada_ibge1.loc[area_plantada_ibge1['2020'] == '...', '2020'] = 0
area_plantada_ibge1.loc[area_plantada_ibge1['2021'] == '...', '2021'] = 0

area_plantada_ibge1['2019'] = area_plantada_ibge1['2019'].astype(float).round(0)
area_plantada_ibge1['2020'] = area_plantada_ibge1['2020'].astype(float).round(0)
area_plantada_ibge1['2021'] = area_plantada_ibge1['2021'].astype(float).round(0)

# %%
area_plantada_ibge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5563 entries, 33 to 5595
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cidade  5563 non-null   object
#  1   2019    5563 non-null   float64
#  2   2020    5563 non-null   float64
#  3   2021    5563 non-null   float64
#  4   Estado  5563 non-null   object
#  5   Sigla   5563 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 304.2+ KB

# %%
# Criando um Groupby para o MT
group = area_plantada_ibge1.loc[area_plantada_ibge1['Sigla'] == 'MT', ['Sigla', '2019', '2020', '2021']].groupby('Sigla').sum()

print(group)
# Out:
#             2019       2020        2021
# Sigla
# MT     9724213.0  9989649.0  10461712.0

# %%
# Fazendo o concat dos DataFrames group e agua_boa
merged_df = pd.concat([group, agua_boa[['Cidade', '2019', '2020', '2021']]], axis=0)


display(merged_df)
# Out:
#            2019       2020        2021    Cidade
# MT    9724213.0  9989649.0  10461712.0       NaN
# 2281          -          -           -  Água Boa
# 5209     160000     178000      175000  Água Boa

# %%
merged_df = merged_df.drop(index=2281)
display(merged_df)
# Out:
#            2019       2020        2021    Cidade
# MT    9724213.0  9989649.0  10461712.0       NaN
# 5209     160000     178000      175000  Água Boa

# %%
merged_df.to_excel('Agua Boa.xlsx')
